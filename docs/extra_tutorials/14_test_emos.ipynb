# %% [markdown]
# ## 14. Benchmarking pyfeat Emotion detection algorithms using data
# *written by Tiankang Xie*
#
# In the tutorial we will demonstrate how to evaluate pyfeat emotion detection algorithms with evaluation data.
# The evaluative data comes from a subset of affectnet. Please see the csv file inside this tutorial folder for more details

# %%
import sys
import torch
import torch.nn as nn
import math
from feat.utils import set_torch_device
import torch.nn.functional as F
from copy import deepcopy
import numpy as np
from skimage import draw
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
from feat.utils.image_operations import extract_face_from_landmarks

from PIL import Image
from itertools import product
import os 
from torchvision.transforms import Compose, Normalize, Grayscale

import pandas as pd
from tqdm import tqdm
from feat import Detector

from joblib import delayed, Parallel
from torchvision.utils import save_image
from torchvision.io import read_image, read_video
from torch.utils.data import Dataset
from feat.transforms import Rescale
import glob
from skimage.feature import hog
import pickle
import joblib
from sklearn.metrics import f1_score
import xgboost as xgb
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from sklearn import preprocessing

from tqdm import tqdm

# %%
data_dir = '/Storage/Data/AffectNet/Manual_Annot/Manually_Annotated_Images/'
save_result_dir = '/Storage/Projects/pyfeat_testing/Data_Eshin/emo_test/'
test_file_csv = pd.read_csv('/Storage/Projects/pyfeat_testing/Data_Eshin/emo_test/affectnet_testSubset.csv', index_col=0)
inp_fnames = [data_dir + fp for fp in test_file_csv.subDirectory_filePath]
test_file_csv['filename'] = test_file_csv.subDirectory_filePath.apply(lambda x: os.path.basename(x).split('.')[0])

# %% [markdown]
# # 1. Test ResmaskNet

# %%
detector = Detector(face_model='retinaface',emotion_model='resmasknet', landmark_model="mobilefacenet", au_model='xgb', device='cuda')
# Out:
# /home/tiankang/anaconda3/envs/py38/lib/python3.8/site-packages/torchvision/models/_utils.py:135: UserWarning: Using 'backbone_name' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /home/tiankang/anaconda3/envs/py38/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
predicted_data = []
bad_file = 0
for inp_name in tqdm(inp_fnames):
    try:
        img_df = detector.detect_image(input_file_list=inp_name, output_size=None, batch_size=1, num_workers=1)
        emo_df = img_df[['anger','disgust','fear','happiness','sadness','surprise','neutral']]
        emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
        predicted_data.append(emo_df)
    except:
        bad_file += 1
        continue;
predicted_data = pd.concat(predicted_data)
predicted_data.to_csv(save_result_dir+'resmasknet_bench_result.csv')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]  1.58it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]  1.52it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.70it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.73it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.59it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.70it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.59it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.73it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.73it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.60it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.52it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.64it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.56it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.43it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.41it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.52it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.56it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.56it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.46it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.64it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:01<?, ?it/s],  1.56it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.34it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:01<?, ?it/s],  1.44it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.38it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s],  1.43it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]t/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.51it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]5,  1.45it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.46it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# ...
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]6it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]7it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]9it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]3it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]31,  1.24it/s]
#   0%|          | 0/1 [00:01<?, ?it/s]32,  1.17it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]7it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]3it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]6it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]5it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]0it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]2it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]26,  1.17it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]4it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]7it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]1it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]1it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]4it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.31it/s]4it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]5it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]18,  1.24it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]7it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]17,  1.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]6it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]9it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]2it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:01<?, ?it/s]13,  1.25it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]6it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]9it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]0it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]9it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]3it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]6it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]4it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]2it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]2it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]3it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]04,  1.23it/s]
#   0%|          | 0/1 [00:01<?, ?it/s]04,  1.15it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]8s/it]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]2s/it]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
# 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]5it/s]
# /tmp/ipykernel_258365/3026939011.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emo_df['filename'] = os.path.basename(inp_name).split('.')[0]
#   0%|          | 0/1 [00:00<?, ?it/s]00,  1.12it/s]
# 100%|██████████| 3500/3500 [47:22<00:00,  1.23it/s]

# %%
def test_emo_resmasknet():

    a1 = pd.read_csv(save_result_dir+'resmasknet_bench_result.csv', index_col=0)
    a2 = pd.merge(a1, test_file_csv, on=['filename'])

    lb = preprocessing.LabelBinarizer()
    emo_labels_bi = lb.fit_transform(a2.expression)
    emo_preds = np.round(a2[['anger', "disgust", "fear", "happiness", "sadness", "surprise", "neutral"]])

    emo_result = []
    for i in range(7):
        print(f1_score(emo_labels_bi[:, i], emo_preds.iloc[:, i]))
        emo_result.append(f1_score(emo_labels_bi[:, i], emo_preds.iloc[:, i]))
    
    arrangement_df_p1 = pd.DataFrame(emo_labels_bi, columns=['anger_label', "disgust_label", "fear_label", "happiness_label", "sadness_label", "surprise_label", "neutral_label"])
    arrangement_df_p2 = emo_preds.rename(columns={'anger':'anger_pred', "disgust":'disgust_pred', 
                                                "fear": 'fear_pred', "happiness":'happiness_pred', "sadness":'sadness_pred', "surprise":'surprise_pred', "neutral":'neutral_pred'})
    arrangement_df = pd.concat((arrangement_df_p1, arrangement_df_p2), 1)

    return emo_result, arrangement_df

# %%
rmn_result, rmn_individuals = test_emo_resmasknet()
# Out:
# 0.4864197530864197
# 0.5058823529411764
# 0.45000000000000007
# 0.766118836915297
# 0.5351418002466091
# 0.5185185185185186
# 0.47761194029850745
# /tmp/ipykernel_258365/3162037035.py:18: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   arrangement_df = pd.concat((arrangement_df_p1, arrangement_df_p2), 1)

# %% [markdown]
# ## SVM model

# %%
detector = Detector(face_model='retinaface',emotion_model='svm', landmark_model="mobilefacenet", au_model='xgb', device='cuda')

# %%
predicted_data = []
for inp_name in tqdm(inp_fnames):
    try:
        eye_df = detector.detect_image(input_file_list=inp_name, output_size=None, batch_size=1, num_workers=1)
        eye_new_df = eye_df[['anger','disgust','fear','happiness','sadness','surprise','neutral']]
        eye_new_df['filename'] = os.path.basename(inp_name).split('.')[0]
        predicted_data.append(eye_new_df)
    except:
        continue;
        
predicted_data = pd.concat(predicted_data)
predicted_data.to_csv(save_result_dir+'svm_bench_result.csv')

# %%
def test_svm_resmasknet():

    a1 = pd.read_csv(save_result_dir+'svm_bench_result.csv', index_col=0)
    a2 = pd.merge(a1, test_file_csv, on=['filename'])

    lb = preprocessing.LabelBinarizer()
    emo_labels_bi = lb.fit_transform(a2.expression)
    emo_preds = np.round(a2[['anger', "disgust", "fear", "happiness", "sadness", "surprise", "neutral"]])

    emo_result = []
    for i in range(7):
        print(f1_score(emo_labels_bi[:, i], emo_preds.iloc[:, i]))
        emo_result.append(f1_score(emo_labels_bi[:, i], emo_preds.iloc[:, i]))
    
    arrangement_df_p1 = pd.DataFrame(emo_labels_bi, columns=['anger_label', "disgust_label", "fear_label", "happiness_label", "sadness_label", "surprise_label", "neutral_label"])
    arrangement_df_p2 = emo_preds.rename(columns={'anger':'anger_pred', "disgust":'disgust_pred', 
                                                "fear": 'fear_pred', "happiness":'happiness_pred', "sadness":'sadness_pred', "surprise":'surprise_pred', "neutral":'neutral_pred'})
    arrangement_df = pd.concat((arrangement_df_p1, arrangement_df_p2), 1)

    return emo_result, arrangement_df

# %%
svm_result, svm_individuals = test_svm_resmasknet()
